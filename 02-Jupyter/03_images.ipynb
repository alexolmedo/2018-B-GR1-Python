# %%
import numpy as np
# pip install scipy
from scipy import misc

# %%
mapache = misc.face()

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()

# %%
mapache_parcial = mapache[384:,512:,:]
plt.imshow(mapache_parcial)
plt.show()

# %%
mapache_parte1, mapache_parte2 = np.split(mapache,2,axis=1)
plt.imshow(mapache_parte1)
plt.show()
plt.imshow(mapache_parte2)
plt.show()

# %%
mapache_frankenstein = np.concatenate([mapache_parte1,mapache_parte2],axis=1)
plt.imshow(mapache_frankenstein)
plt.show()
