# %% [markdown]
# # Análisis iPhone

# %% [markdown]
# El objetivo del presente proyecto es realizar una comparativa de las diferentes versiones de iPhone, y cómo ha variado la percepción del público a través de los años

# %% [markdown]
# ## Web scraping
# En primer lugar se requirió obtener las características de todos los modelos de iPhone que han sido lanzados hasta febrero de 2018. Esta información fue obtenida a traves de scraping a la página web: http://socialcompare.com/en/comparison/apple-iphone-product-line-comparison

# %%
from IPython.display import Image
Image("img/web.png")

# %% [markdown]
# Mediante un spider de Scrapy se seleccionó las datos más relevantes y se almacenaron en un archivo csv. Posteriormente este archivo fue importado a un dataframe de Pandas.

# %%
import pandas
df = pandas.read_csv('../scrapy/iphone.csv')
print(df)
# Out:
#             modelo  pulgadas_pantalla  resolucion_camara    ram  bateria  \
# 0        iPhone XS                5.8                 12  4.000     2658
# 1    iPhone XS Max                6.5                 12  4.000     3174
# 2        iPhone XR                6.1                 12  3.000     2942
# 3    iPhone X (10)                5.8                 12  3.000     2716
# 4    iPhone 8 Plus                5.5                 12  3.000     2675
# 5         iPhone 8                4.7                 12  2.000     1821
# 6        iPhone SE                4.0                 12  2.000     1624
# 7    iPhone 7 Plus                5.5                 12  3.000     2900
# 8         iPhone 7                4.7                 12  2.000     1960
# 9   iPhone 6s Plus                5.5                 12  2.000     2750
# 10       iPhone 6s                4.7                 12  2.000     1715
# 11   iPhone 6 Plus                5.5                  8  1.000     2915
# 12        iPhone 6                4.7                  8  1.000     1810
# 13       iPhone 5S                4.0                  8  1.000     1570
# 14       iPhone 5C                4.0                  8  1.000     1507
# 15        iPhone 5                4.0                  8  1.000     1440
# 16       iPhone 4S                3.5                  8  1.000     1432
# 17        iPhone 4                3.5                  5  0.512     1420
# 18      iPhone 3GS                3.5                  3  0.256     1219
#
#     almacenamiento       fecha
# 0              512  2018-09-28
# 1              512  2018-09-28
# 2              256  2018-10-26
# 3              256  2017-10-27
# 4              256  2017-09-15
# 5              256  2017-09-15
# 6               64  2016-03-21
# 7              256  2016-09-16
# 8               32  2016-09-16
# 9              128  2015-09-12
# 10             128  2015-09-12
# 11             128  2014-09-09
# 12             128  2014-09-09
# 13              64  2013-09-10
# 14              32  2013-09-10
# 15              64  2012-09-21
# 16              64  2011-10-14
# 17              32  2010-06-24
# 18              32  2009-06-19
